# %%
import numpy as np
from scipy import stats

# Example data
data = np.array([4, 8, 15, 16, 23, 42, 108])

# Calculating Z-scores
z_scores = stats.zscore(data)

# %%
# Identifying outliers
outliers = data[(z_scores < -2) | (z_scores > 2)]
print("Z-scores:", z_scores)
print("Outliers:", outliers)

# %%
import numpy as np

# Example data (can be a list, a NumPy array, or a Pandas DataFrame column)
data = np.array([4, 8, 15, 16, 23, 42, 108])

# Calculating the mean
mean = np.mean(data)

# Centering the data
centered_data = data - mean

print("Centered Data:", centered_data)
# Out:
# Centered Data: [-26.85714286 -22.85714286 -15.85714286 -14.85714286  -7.85714286
#   11.14285714  77.14285714]
